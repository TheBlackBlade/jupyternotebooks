# %%
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('csv/master.csv', delimiter=';')
df2 = df[df.wr!='total']
df2 = df2[df.sim_tool!='None']
df2['sum_rel'] = df2.summe/df2.installed_p
# Out:
# D:\Anaconda\envs\p_py37\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
box_ax1 = df2.boxplot('sum_rel','wr',rot = 30,figsize=(5,6))
plt.savefig('sum_rel_for_wr.png')
box_ax2 = df2.boxplot('sum_rel','inv',rot = 30,figsize=(5,6))
plt.savefig('sum_rel_for_inv.png')
box_ax3 = df2.boxplot('sum_rel','module',rot = 30,figsize=(5,6))
plt.savefig('sum_rel_for_module.png')

# %%
df2['colors'] = df
df2.plot('wr','jan',kind='bar', color=df.sim_tool)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-05cf359626b9> in <module>
# ----> 1 df2.plot('wr','jan',kind='bar', color=df.sim_tool)
#
# D:\Anaconda\envs\p_py37\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     845                     data.columns = label_name
#     846
# --> 847         return plot_backend.plot(data, kind=kind, **kwargs)
#     848
#     849     __call__.__doc__ = __doc__
#
# D:\Anaconda\envs\p_py37\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# D:\Anaconda\envs\p_py37\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
# ...

# %%
# Out:
#    sim_tool     weather     wr      module   inv  installed_p    summe    jan  \
# 0   polysun    standard    wr1  schott_105   dlx        3.150   3111.0   80.4
# 1   polysun    standard    wr2    aleo_285   dlx        3.135   2825.0   70.2
# 2   polysun    standard    wr3    aleo_240   dlx        3.360   3051.0   75.2
# 3   polysun    standard    wr4    aleo_245   sma        3.185   2924.0   72.3
# 4   polysun    standard    wr5  schott_105   sma        3.150   3170.0   80.8
# 5   polysun    standard  total        None  None       15.980  15081.0  378.9
# 6   polysun  htw_wetter    wr1  schott_105   dlx        3.150   3228.0   45.9
# 7   polysun  htw_wetter    wr2    aleo_285   dlx        3.135   2933.0   36.4
# 8   polysun  htw_wetter    wr3    aleo_240   dlx        3.360   3167.0   37.7
# 9   polysun  htw_wetter    wr4    aleo_245   sma        3.185   3032.0   35.9
# 10  polysun  htw_wetter    wr5  schott_105   sma        3.150   3286.0   44.6
# ...

# %%
df[df.wr=='total']
# Out:
#    sim_tool     weather     wr module   inv  installed_p    summe    jan  \
# 5   polysun    standard  total   None  None        15.98  15081.0  378.9
# 11  polysun  htw_wetter  total   None  None        15.98  15646.0  200.5
# 17  polysun    openfred  total   None  None        15.98  14041.0  267.5
# 23    pvsol    standard  total   None  None        15.98  14659.0  336.7
# 29    pvsol  htw_wetter  total   None  None        15.98  14596.5  330.7
# 35    pvsol    openfred  total   None  None        15.98  14519.6  328.0
# 41     None        None  total   None  None        15.98  16534.9  223.5
#
#       feb     mrz     apr     mai     jun     jul     aug     sep    okt  \
# 5   630.0  1216.0  1635.0  2125.0  2126.0  2115.0  1918.0  1384.0  878.0
# 11  749.0  1154.0  1872.0  2095.0  2168.0  2252.0  2210.0  1418.0  877.0
# 17  733.0  1004.0  1692.0  2034.0  1942.0  1996.0  1881.0  1242.0  742.0
# 23  557.0  1158.1  1808.3  2045.7  2082.1  2092.4  1789.9  1346.7  842.4
# ...
